# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential
([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # fx 4 klasser af tumorer men i vores tilfælde går vi med binary, så 4 skal skifte ud med 1 og softmax ud med sigmoid
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(train_data, validation_data=test_data, epochs=10)

model.save('../models/cnn_model.h5')

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# --- Byg model ---
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
    MaxPooling2D(2,2),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # binary class
])

# --- Kompiler model ---
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',   
    metrics=['accuracy']
)

# --- Træn model ---
history = model.fit(
    train_data,            # din træningsgenerator
    validation_data=test_data,   # din valideringsgenerator
    epochs=10
)

# --- Gem model ---
os.makedirs("../models", exist_ok=True)   # sørger for at mappen findes
model.save("../models/cnn_model.h5")

print(" Model er trænet og gemt som '../models/cnn_model.h5'")
